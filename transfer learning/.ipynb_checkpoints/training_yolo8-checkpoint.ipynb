# %% [markdown]
# # Yolo 8 food detection

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.0.201-py3-none-any.whl (644 kB)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (0.14.0)
# Requirement already satisfied: requests>=2.23.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (2.28.1)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (6.0)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (4.64.1)
# Collecting opencv-python>=4.6.0
#   Downloading opencv_python-4.8.1.78-cp37-abi3-win_amd64.whl (38.1 MB)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (0.11.2)
# Collecting thop>=0.1.1
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: torch>=1.8.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (1.13.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (1.25.0)
# Requirement already satisfied: psutil in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (5.9.4)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from ultralytics) (9.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.33.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from pandas>=1.1.4->ultralytics) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from requests>=2.23.0->ultralytics) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.13)
# Requirement already satisfied: typing_extensions in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from torch>=1.8.0->ultralytics) (4.1.1)
# Requirement already satisfied: colorama in c:\users\piotr\anaconda3\envs\py10\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Installing collected packages: thop, py-cpuinfo, opencv-python, ultralytics
# Successfully installed opencv-python-4.8.1.78 py-cpuinfo-9.0.0 thop-0.1.1.post2209072238 ultralytics-8.0.201

# %%
from ultralytics import YOLO
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# Load a pretrained YOLO model
model = YOLO("yolov8n.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]

# %%
cat_dog = Image.open("cat_dog.jpg")
# cat_dog = cat_dog.resize((624,416))
cat_dog = np.asarray(cat_dog)
plt.imshow(cat_dog)

# %%
cat_dog.shape
# Out:
# (415, 612, 3)

# %%
result= model.predict(cat_dog)
# Out:
# 0: 448x640 1 dog, 1 sheep, 1 bear, 254.0ms
# Speed: 7.0ms preprocess, 254.0ms inference, 19.0ms postprocess per image at shape (1, 3, 448, 640)

# %%
Image.fromarray(result[0].plot())
# Out:
# <PIL.Image.Image image mode=RGB size=612x415 at 0x24C1A68C0D0>
